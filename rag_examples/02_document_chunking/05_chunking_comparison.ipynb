# %% [markdown]
# # 切片方法对比（Chunking Comparison）
#
# **用途**：教学演示 - 对比四种切片方法的效果
#
# **核心概念**：
# - 固定规则切片
# - 滑动窗口切片
# - AI 辅助切片
# - 概要生成切片

# %% [markdown]
# ## 运行前检查
#
# 1. 已安装依赖：pip install -r ../requirements.txt
# 2. 已完成 01-04 切片方法的学习

# %%
import sys
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# ## 理解切片对比
#
# ### 为什么要对比切片方法？
#
# **不同切片方法的特点**：
# - 固定规则：简单快速，但可能切断语义
# - 滑动窗口：保持上下文，有数据冗余
# - AI 辅助：语义完整，需要 API 调用
# - 概要生成：检索精准，额外生成成本
#
# ### 选择切片方法的考虑因素
# 1. 文档长度
# 2. 文档结构（是否有清晰段落/章节）
# 3. 检索精度要求
# 4. 成本和性能限制
# 5. 实时性要求
#
# ### 对比维度
# - 切片质量（语义完整性）
# - 处理速度
# - 存储成本
# - 检索效果
# - 实现复杂度

# %% [markdown]
# ## 导入切片函数

# %%
def fixed_chunking(text, chunk_size=100):
    """固定字符切片"""
    chunks = []
    for i in range(0, len(text), chunk_size):
        chunks.append(text[i:i + chunk_size])
    return chunks

def sliding_window_chunking(text, window_size=100, step_size=50):
    """滑动窗口切片"""
    chunks = []
    start = 0
    while start < len(text):
        chunks.append(text[start:start + window_size])
        start += step_size
        if start >= len(text):
            break
    return chunks

def ai_chunking(text, max_chunk_size=150):
    """模拟 AI 切片（按段落）"""
    import re
    paragraphs = re.split(r'\n\s*\n', text)
    chunks = [p.strip() for p in paragraphs if p.strip()]
    return chunks

def summary_chunking(text):
    """模拟概要切片（返回原文 + 摘要）"""
    import re
    paragraphs = re.split(r'\n\s*\n', text)
    chunks = []
    summaries = []
    for p in paragraphs:
        p = p.strip()
        if p:
            chunks.append(p)
            first_sentence = re.split(r'[.!?!.!?。！？]+', p)[0]
            summaries.append(first_sentence[:30] + "..." if len(first_sentence) > 30 else first_sentence)
    return chunks, summaries

# %% [markdown]
# ## 示例 1: 同一切片在不同方法下的效果

# %%
def compare_all_methods(text):
    print("=" * 60)
    print("示例 1: 四种切片方法对比")
    print("=" * 60)

    print(f"原始文本长度：{len(text)} 字符\n")
    print(f"原始文本:\n{text[:200]}...\n")
    print("-" * 60)

    fixed = fixed_chunking(text, chunk_size=100)
    print(f"\n1. 固定字符切片 (chunk_size=100)")
    print(f"   切片数量：{len(fixed)}")
    for i, chunk in enumerate(fixed[:4]):
        print(f"   [{i+1}] {len(chunk)}字：{chunk[:40]}...")

    sliding = sliding_window_chunking(text, window_size=100, step_size=50)
    print(f"\n2. 滑动窗口切片 (window=100, step=50)")
    print(f"   切片数量：{len(sliding)}")
    for i, chunk in enumerate(sliding[:4]):
        print(f"   [{i+1}] {len(chunk)}字：{chunk[:40]}...")

    ai = ai_chunking(text, max_chunk_size=150)
    print(f"\n3. AI 辅助切片 (按段落)")
    print(f"   切片数量：{len(ai)}")
    for i, chunk in enumerate(ai[:4]):
        print(f"   [{i+1}] {len(chunk)}字：{chunk[:40]}...")

    summary_chunks, summary_list = summary_chunking(text)
    print(f"\n4. 概要生成切片")
    print(f"   切片数量：{len(summary_chunks)}")
    for i, (chunk, summ) in enumerate(zip(summary_chunks[:4], summary_list[:4])):
        print(f"   [{i+1}] 摘要：{summ}")

# %%
text = """人工智能（AI）是模拟人类智能的计算机科学领域。它包括机器学习、深度学习、自然语言处理等多个分支。AI 从 1956 年诞生至今，已经经历了多次发展浪潮。

机器学习是 AI 的核心技术之一。它通过训练数据让计算机自动学习规律，无需显式编程。监督学习、无监督学习、强化学习是三种主要的学习范式。

深度学习是机器学习的子集，使用多层神经网络模拟人脑。它在图像识别、语音识别等领域取得了突破性进展。卷积神经网络（CNN）和循环神经网络（RNN）是两种经典架构。

自然语言处理（NLP）让计算机理解和生成人类语言。应用包括机器翻译、情感分析、智能客服等。近年来，大语言模型（LLM）在 NLP 领域引发了革命。

计算机视觉（CV）让计算机能够"看懂"图像和视频。应用包括人脸识别、物体检测、医学图像分析等。深度学习大幅提升了 CV 的性能。"""

compare_all_methods(text)
# Out:
# ============================================================
# 示例 1: 四种切片方法对比
# ============================================================
# 原始文本长度：370 字符
#
# 原始文本:
# 人工智能（AI）是模拟人类智能的计算机科学领域。它包括机器学习、深度学习、自然语言处理等多个分支。AI 从 1956 年诞生至今，已经经历了多次发展浪潮。
#
# 机器学习是 AI 的核心技术之一。它通过训练数据让计算机自动学习规律，无需显式编程。监督学习、无监督学习、强化学习是三种主要的学习范式。
#
# 深度学习是机器学习的子集，使用多层神经网络模拟人脑。它在图像识别、语音识别等领域取得了突破性进展。卷积...
#
# ------------------------------------------------------------
#
# 1. 固定字符切片 (chunk_size=100)
#    切片数量：4
#    [1] 100字：人工智能（AI）是模拟人类智能的计算机科学领域。它包括机器学习、深度学习、自然语...
#    [2] 100字：练数据让计算机自动学习规律，无需显式编程。监督学习、无监督学习、强化学习是三种主...
#    [3] 100字：神经网络（CNN）和循环神经网络（RNN）是两种经典架构。
#
# 自然语言处理（NL...
#    [4] 70字：了革命。
#
# 计算机视觉（CV）让计算机能够"看懂"图像和视频。应用包括人脸识别、...
#
# 2. 滑动窗口切片 (window=100, step=50)
#    切片数量：8
#    [1] 100字：人工智能（AI）是模拟人类智能的计算机科学领域。它包括机器学习、深度学习、自然语...
#    [2] 100字：I 从 1956 年诞生至今，已经经历了多次发展浪潮。
#
# 机器学习是 AI 的核...
#    [3] 100字：练数据让计算机自动学习规律，无需显式编程。监督学习、无监督学习、强化学习是三种主...
#    [4] 100字：度学习是机器学习的子集，使用多层神经网络模拟人脑。它在图像识别、语音识别等领域取...
#
# 3. AI 辅助切片 (按段落)
#    切片数量：5
#    [1] 77字：人工智能（AI）是模拟人类智能的计算机科学领域。它包括机器学习、深度学习、自然语...
#    [2] 68字：机器学习是 AI 的核心技术之一。它通过训练数据让计算机自动学习规律，无需显式编...
#    [3] 80字：深度学习是机器学习的子集，使用多层神经网络模拟人脑。它在图像识别、语音识别等领域...
#    [4] 73字：自然语言处理（NLP）让计算机理解和生成人类语言。应用包括机器翻译、情感分析、智...
#
# 4. 概要生成切片
#    切片数量：5
#    [1] 摘要：人工智能（AI）是模拟人类智能的计算机科学领域
#    [2] 摘要：机器学习是 AI 的核心技术之一
#    [3] 摘要：深度学习是机器学习的子集，使用多层神经网络模拟人脑
#    [4] 摘要：自然语言处理（NLP）让计算机理解和生成人类语言

# %% [markdown]
# ## 示例 2: 切片质量评估

# %%
def evaluate_chunk_quality(chunks):
    """
    评估切片质量的简单指标
    
    指标包括：
    - 平均长度
    - 长度标准差（越小说明越均匀）
    - 完整性评分（基于是否有完整句子）
    """
    import statistics

    if not chunks:
        return None

    lengths = [len(c) for c in chunks]
    avg_length = statistics.mean(lengths)
    std_length = statistics.stdev(lengths) if len(lengths) > 1 else 0

    complete_ratio = sum(1 for c in chunks if '。' in c or '.' in c) / len(chunks)

    return {
        "avg_length": avg_length,
        "std_length": std_length,
        "complete_ratio": complete_ratio,
        "total_chunks": len(chunks)
    }

# %%
def demo_quality_evaluation():
    print()
    print("=" * 60)
    print("示例 2: 切片质量评估")
    print("=" * 60)

    text = """人工智能（AI）是模拟人类智能的计算机科学领域。它包括机器学习、深度学习、自然语言处理等多个分支。

机器学习是 AI 的核心技术之一。它通过训练数据让计算机自动学习规律，无需显式编程。

深度学习使用多层神经网络模拟人脑。它在图像识别、语音识别等领域取得了突破性进展。

自然语言处理让计算机理解和生成人类语言。应用包括机器翻译、情感分析、智能客服等。"""

    methods = {
        "固定字符 (100)": fixed_chunking(text, 100),
        "固定字符 (150)": fixed_chunking(text, 150),
        "滑动窗口 (100/50)": sliding_window_chunking(text, 100, 50),
        "AI 辅助 (段落)": ai_chunking(text),
    }

    print(f"文本长度：{len(text)} 字符\n")
    print("质量评估结果:\n")

    results = []
    for name, chunks in methods.items():
        metrics = evaluate_chunk_quality(chunks)
        results.append((name, metrics))
        print(f"【{name}】")
        print(f"  切片数：{metrics['total_chunks']}")
        print(f"  平均长度：{metrics['avg_length']:.1f} 字")
        print(f"  长度波动：{metrics['std_length']:.1f} (越小越均匀)")
        print(f"  完整句比例：{metrics['complete_ratio']*100:.0f}%")
        print()

    print("-" * 60)
    best = max(results, key=lambda x: x[1]['complete_ratio'])
    print(f"推荐：语义完整性最佳 → {best[0]}")

demo_quality_evaluation()
# Out:
# ============================================================
# 示例 2: 切片质量评估
# ============================================================
# 文本长度：177 字符
#
# 质量评估结果:
#
# 【固定字符 (100)】
#   切片数：2
#   平均长度：88.5 字
#   长度波动：16.3 (越小越均匀)
#   完整句比例：100%
#
# 【固定字符 (150)】
#   切片数：2
#   平均长度：88.5 字
#   长度波动：87.0 (越小越均匀)
#   完整句比例：100%
#
# 【滑动窗口 (100/50)】
#   切片数：4
#   平均长度：76.0 字
#   长度波动：34.4 (越小越均匀)
#   完整句比例：100%
#
# 【AI 辅助 (段落)】
#   切片数：4
#   平均长度：42.8 字
#   长度波动：4.3 (越小越均匀)
#   完整句比例：100%
#
# ------------------------------------------------------------
# 推荐：语义完整性最佳 → 固定字符 (100)

# %% [markdown]
# ## 示例 3: 检索效果模拟对比

# %%
def simulate_search(query, chunks):
    """
    模拟检索：基于关键词重叠度
    """
    query_words = set(query.lower())

    scores = []
    for i, chunk in enumerate(chunks):
        chunk_words = set(chunk.lower())
        overlap = len(query_words & chunk_words)
        scores.append((i, overlap, chunk))

    scores.sort(key=lambda x: x[1], reverse=True)
    return scores[:3]

# %%
def demo_search_comparison():
    print()
    print("=" * 60)
    print("示例 3: 检索效果模拟对比")
    print("=" * 60)

    text = """人工智能（AI）是模拟人类智能的计算机科学领域。它包括机器学习、深度学习、自然语言处理等多个分支。

机器学习是 AI 的核心技术之一。它通过训练数据让计算机自动学习规律，无需显式编程。监督学习、无监督学习、强化学习是三种主要的学习范式。

深度学习是机器学习的子集，使用多层神经网络模拟人脑。它在图像识别、语音识别等领域取得了突破性进展。卷积神经网络（CNN）和循环神经网络（RNN）是两种经典架构。

自然语言处理（NLP）让计算机理解和生成人类语言。应用包括机器翻译、情感分析、智能客服等。近年来，大语言模型（LLM）在 NLP 领域引发了革命。"""

    fixed_chunks = fixed_chunking(text, 100)
    sliding_chunks = sliding_window_chunking(text, 100, 50)
    ai_chunks = ai_chunking(text)

    queries = [
        "机器学习有几种学习方式？",
        "深度学习在图像识别的应用",
        "自然语言处理包括什么"
    ]

    for query in queries:
        print(f"\n查询：{query}")
        print("-" * 50)

        for method_name, chunks in [
            ("固定字符", fixed_chunks),
            ("滑动窗口", sliding_chunks),
            ("AI 辅助", ai_chunks)
        ]:
            results = simulate_search(query, chunks)
            top_score = results[0][1] if results else 0
            print(f"  {method_name}: 最高匹配度={top_score}")
        print()

demo_search_comparison()
# Out:
# ============================================================
# 示例 3: 检索效果模拟对比
# ============================================================
#
# 查询：机器学习有几种学习方式？
# --------------------------------------------------
#   固定字符: 最高匹配度=6
#   滑动窗口: 最高匹配度=6
#   AI 辅助: 最高匹配度=6
#
#
# 查询：深度学习在图像识别的应用
# --------------------------------------------------
#   固定字符: 最高匹配度=11
#   滑动窗口: 最高匹配度=11
#   AI 辅助: 最高匹配度=11
#
#
# 查询：自然语言处理包括什么
# --------------------------------------------------
#   固定字符: 最高匹配度=8
#   滑动窗口: 最高匹配度=8
#   AI 辅助: 最高匹配度=8

# %% [markdown]
# ## 示例 4: 文件切片对比

# %%
def compare_file_chunking(file_path):
    print("=" * 60)
    print("示例 4: 文件切片对比")
    print("=" * 60)

    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            text = f.read()
    except FileNotFoundError:
        print(f"✗ 文件不存在：{file_path}")
        return

    print(f"文件：{file_path}")
    print(f"文本长度：{len(text)} 字符\n")

    methods = {
        "固定字符 (200)": fixed_chunking(text, 200),
        "滑动窗口 (200/100)": sliding_window_chunking(text, 200, 100),
        "AI 辅助 (段落)": ai_chunking(text),
    }

    print("切片结果对比：\n")

    for name, chunks in methods.items():
        print(f"【{name}】")
        print(f"  切片数量：{len(chunks)}")
        print(f"  平均长度：{sum(len(c) for c in chunks)/len(chunks):.1f} 字")
        print(f"  预览：")
        for i, chunk in enumerate(chunks[:2]):
            preview = chunk[:50].replace('\n', ' ')
            print(f"    [{i+1}] {preview}...")
        print()

# %%
file_path = "../data/txt/milvus_intro.txt"
compare_file_chunking(file_path)
# Out:
# ============================================================
# 示例 4: 文件切片对比
# ============================================================
# 文件：../data/txt/milvus_intro.txt
# 文本长度：448 字符
#
# 切片结果对比：
#
# 【固定字符 (200)】
#   切片数量：3
#   平均长度：149.3 字
#   预览：
#     [1] Milvus 是一个开源的向量数据库，专门用于存储和搜索向量数据。 它由 Zilliz 公司开发，于...
#     [2] 索引层：构建各种索引加速检索 - 计算层：处理查询请求和相似度计算 - 接入层：提供 API 接口和...
#
# 【滑动窗口 (200/100)】
#   切片数量：5
#   平均长度：159.2 字
#   预览：
#     [1] Milvus 是一个开源的向量数据库，专门用于存储和搜索向量数据。 它由 Zilliz 公司开发，于...
#     [2]  可扩展：支持分布式部署，水平扩展 - 易用性：提供多种语言的客户端 SDK - 生态丰富：与主流 ...
#
# 【AI 辅助 (段落)】
#   切片数量：5
#   平均长度：87.8 字
#   预览：
#     [1] Milvus 是一个开源的向量数据库，专门用于存储和搜索向量数据。 它由 Zilliz 公司开发，于...
#     [2] Milvus 的核心特点： - 高性能：支持亿级向量数据的毫秒级检索 - 可扩展：支持分布式部署，水...

# %% [markdown]
# ## 示例 5: 综合评分表

# %%
def comprehensive_comparison_table():
    print("=" * 60)
    print("示例 5: 综合评分表")
    print("=" * 60)

    print("""
┌────────────────────────────────────────────────────────────────────┐
│ 四种切片方法综合对比                                                │
├─────────────────┬──────────┬──────────┬──────────┬─────────────────┤
│      维度        │ 固定规则  │ 滑动窗口  │  AI 辅助   │   概要生成       │
├─────────────────┼──────────┼──────────┼──────────┼─────────────────┤
│ 实现难度        │  ⭐        │  ⭐⭐       │  ⭐⭐⭐      │   ⭐⭐⭐          │
│                 │ 非常简单   │ 简单      │ 中等      │   中等          │
├─────────────────┼──────────┼──────────┼──────────┼─────────────────┤
│ 处理速度        │  ⭐⭐⭐⭐     │  ⭐⭐⭐      │  ⭐⭐       │   ⭐⭐           │
│                 │ 非常快     │ 快        │ 慢 (API)  │ 慢 (API)        │
├─────────────────┼──────────┼──────────┼──────────┼─────────────────┤
│ 语义完整性      │  ⭐⭐       │  ⭐⭐⭐      │  ⭐⭐⭐⭐     │   ⭐⭐⭐⭐         │
│                 │ 较差      │ 较好      │ 好        │ 好              │
├─────────────────┼──────────┼──────────┼──────────┼─────────────────┤
│ 检索精度        │  ⭐⭐       │  ⭐⭐⭐      │  ⭐⭐⭐⭐     │   ⭐⭐⭐⭐⭐        │
│                 │ 一般      │ 良好      │ 优秀      │ 最佳 (用摘要)    │
├─────────────────┼──────────┼──────────┼──────────┼─────────────────┤
│ 存储成本        │  ⭐⭐⭐⭐     │  ⭐⭐⭐      │  ⭐⭐⭐⭐     │   ⭐⭐           │
│                 │ 低        │ 中 (冗余)  │ 低        │ 高 (多存摘要)    │
├─────────────────┼──────────┼──────────┼──────────┼─────────────────┤
│ 适用文档        │ 任意       │ 任意      │ 结构化    │ 长文档          │
├─────────────────┼──────────┼──────────┼──────────┼─────────────────┤
│ 成本            │  无        │  无        │  API 费用   │   API 费用        │
└─────────────────┴──────────┴──────────┴──────────┴─────────────────┘

场景推荐:

| 场景 | 推荐方法 | 理由 |
|------|----------|------|
| 快速原型 | 固定规则 | 实现最快，5 分钟搞定 |
| 生产环境 (通用) | 滑动窗口 | 平衡性能和效果 |
| 高质量 RAG | AI 辅助 + 概要 | 检索精度优先 |
| 长文档检索 | 概要生成 | 减少噪声干扰 |
| 成本敏感 | 滑动窗口 | 无需 API 调用 |
| 实时处理 | 固定规则/滑动窗口 | 低延迟 |
""")

comprehensive_comparison_table()
# Out:
# ============================================================
# 示例 5: 综合评分表
# ============================================================
#
# ┌────────────────────────────────────────────────────────────────────┐
# │ 四种切片方法综合对比                                                │
# ├─────────────────┬──────────┬──────────┬──────────┬─────────────────┤
# │      维度        │ 固定规则  │ 滑动窗口  │  AI 辅助   │   概要生成       │
# ├─────────────────┼──────────┼──────────┼──────────┼─────────────────┤
# │ 实现难度        │  ⭐        │  ⭐⭐       │  ⭐⭐⭐      │   ⭐⭐⭐          │
# │                 │ 非常简单   │ 简单      │ 中等      │   中等          │
# ├─────────────────┼──────────┼──────────┼──────────┼─────────────────┤
# │ 处理速度        │  ⭐⭐⭐⭐     │  ⭐⭐⭐      │  ⭐⭐       │   ⭐⭐           │
# │                 │ 非常快     │ 快        │ 慢 (API)  │ 慢 (API)        │
# ├─────────────────┼──────────┼──────────┼──────────┼─────────────────┤
# │ 语义完整性      │  ⭐⭐       │  ⭐⭐⭐      │  ⭐⭐⭐⭐     │   ⭐⭐⭐⭐         │
# │                 │ 较差      │ 较好      │ 好        │ 好              │
# ├─────────────────┼──────────┼──────────┼──────────┼─────────────────┤
# │ 检索精度        │  ⭐⭐       │  ⭐⭐⭐      │  ⭐⭐⭐⭐     │   ⭐⭐⭐⭐⭐        │
# │                 │ 一般      │ 良好      │ 优秀      │ 最佳 (用摘要)    │
# ├─────────────────┼──────────┼──────────┼──────────┼─────────────────┤
# │ 存储成本        │  ⭐⭐⭐⭐     │  ⭐⭐⭐      │  ⭐⭐⭐⭐     │   ⭐⭐           │
# │                 │ 低        │ 中 (冗余)  │ 低        │ 高 (多存摘要)    │
# ├─────────────────┼──────────┼──────────┼──────────┼─────────────────┤
# │ 适用文档        │ 任意       │ 任意      │ 结构化    │ 长文档          │
# ├─────────────────┼──────────┼──────────┼──────────┼─────────────────┤
# │ 成本            │  无        │  无        │  API 费用   │   API 费用        │
# └─────────────────┴──────────┴──────────┴──────────┴─────────────────┘
#
# 场景推荐:
#
# | 场景 | 推荐方法 | 理由 |
# |------|----------|------|
# | 快速原型 | 固定规则 | 实现最快，5 分钟搞定 |
# | 生产环境 (通用) | 滑动窗口 | 平衡性能和效果 |
# | 高质量 RAG | AI 辅助 + 概要 | 检索精度优先 |
# | 长文档检索 | 概要生成 | 减少噪声干扰 |
# | 成本敏感 | 滑动窗口 | 无需 API 调用 |
# | 实时处理 | 固定规则/滑动窗口 | 低延迟 |

# %% [markdown]
# ## 示例 6: 选择建议

# %%
def chunking_selection_guide():
    print()
    print("=" * 60)
    print("示例 6: 切片方法选择指南")
    print("=" * 60)

    print("""
┌─────────────────────────────────────────────────────────┐
│ 如何选择切片方法？决策树                                 │
├─────────────────────────────────────────────────────────┤
│                                                         │
│ Q1: 有 Token 预算吗？                                       │
│ │                                                        │
│ ├─ 没有 → 滑动窗口（推荐默认）                           │
│ │                                                        │
│ └─ 有 → Q2                                               │
│                                                         │
│ Q2: 文档平均长度？                                        │
│ │                                                        │
│ ├─ <500 字 → AI 辅助切片（按语义分）                     │
│ │                                                        │
│ └─ >500 字 → Q3                                          │
│                                                         │
│ Q3: 检索精度要求？                                        │
│ │                                                        │
│ ├─ 高 → 概要生成切片（摘 + 原文混合检索）               │
│ │                                                        │
│ └─ 中 → AI 辅助切片                                       │
│                                                         │
└─────────────────────────────────────────────────────────┘

推荐配置:

1. 通用配置（无脑选择）
   方法：滑动窗口
   参数：window=500, step=250（50% 重叠）
   适用：大多数 RAG 场景

2. 高质量配置（有预算）
   方法：AI 辅助 + 概要生成
   参数：按段落分 + 为每段生成摘要
   适用：企业级 RAG、客服系统

3. 快速原型配置
   方法：固定字符
   参数：chunk_size=300
   适用：验证想法、Demo 演示

4. 长文档配置
   方法：概要生成 + 混合检索
   参数：摘要权重 0.6，原文权重 0.4
   适用：文档检索、知识库搜索
""")

chunking_selection_guide()

# %% [markdown]
# ## 总结
#
# 四种切片方法各有优劣：
# - **固定规则**：简单快速，适合快速原型
# - **滑动窗口**：平衡性能，是通用首选
# - **AI 辅助**：语义完整，适合有 API 预算的场景
# - **概要生成**：检索精准，适合长文档
#
# 下一步：03_retrieval_methods/（检索方法）
